# %%
import pandas as pd
import datetime
data = pd.read_csv('/Users/aromerq/Documents/Analitica y BI/Análisis/Capacidad Operacional/Disponota/data2.csv',  sep=',' )

# %%
data.head()
# Out:
#         fecha  cod_formato           formato                 mercado  \
# 0  2021-05-01          200  200  EXPRESS 400  838  Express Mercado 7
# 1  2021-05-01          200  200  EXPRESS 400  829  Express Mercado 9
# 2  2021-05-01          200  200  EXPRESS 400  838  Express Mercado 7
# 3  2021-05-01          819        819  LIDER    848  Mercado Lider 4
# 4  2021-05-01          200  200  EXPRESS 400  838  Express Mercado 7
#
#    store_nbr            indicador  nota     kpi  disponota  \
# 0        242         15% QUIEBRES  10.0    0.35       9.27
# 1        469        18% MODULARES  10.0  100.00       7.62
# 2        242  10% INCONSISTENCIAS  10.0    0.53       9.27
# 3        671  10% INCONSISTENCIAS  10.0    2.67       7.34
# 4        242        18% MODULARES  10.0  100.00       9.27
#
#                                   local               mercado.1
# 0  0242  EK LEOII                        838  Express Mercado 7
# 1  0469  EK OVALLE                       829  Express Mercado 9
# ...

# %%
data['month'] = pd.to_datetime(data['fecha']) 
data['month'] = data['month'].dt.month 

data['year'] = pd.to_datetime(data['fecha']) 
data['year'] = data['year'].dt.year

data['quarter'] = pd.to_datetime(data['fecha'])
data['quarter'] = data['quarter'].dt.quarter

# %%
data.describe()
# Out:
#         cod_formato     store_nbr          nota           kpi     disponota  \
# count  1.245976e+06  1.245976e+06  1.245976e+06  1.245976e+06  1.245976e+06
# mean   7.174705e+02  4.262409e+02  7.261995e+00  2.187987e+02  7.352037e+00
# std    2.320117e+02  2.711717e+02  2.666482e+00  3.776030e+04  1.195399e+00
# min    2.000000e+02  1.000000e+00  1.000000e+00  0.000000e+00  1.800000e-01
# 25%    8.150000e+02  1.690000e+02  5.000000e+00  4.390000e+00  6.650000e+00
# 50%    8.190000e+02  4.980000e+02  8.000000e+00  4.568000e+01  7.480000e+00
# 75%    8.260000e+02  6.230000e+02  1.000000e+01  9.114000e+01  8.180000e+00
# max    8.900000e+02  9.960000e+02  1.000000e+01  1.096830e+07  1.117000e+01
#
#               month          year       quarter
# count  1.245976e+06  1.245976e+06  1.245976e+06
# mean   6.479472e+00  2.021352e+03  2.494734e+00
# std    3.429018e+00  4.774762e-01  1.110043e+00
# min    1.000000e+00  2.021000e+03  1.000000e+00
# ...

# %%
data.tail()
# Out:
#               fecha  cod_formato           formato        mercado  store_nbr  \
# 1245971  2022-05-10          815  815  BOD ACUENTA  869  RM - XIV        992
# 1245972  2022-05-10          815  815  BOD ACUENTA  869  RM - XIV        992
# 1245973  2022-05-10          815  815  BOD ACUENTA  869  RM - XIV        992
# 1245974  2022-05-10          815  815  BOD ACUENTA  869  RM - XIV        992
# 1245975  2022-05-10          815  815  BOD ACUENTA  869  RM - XIV        992
#
#                indicador  nota     kpi  disponota  \
# 1245971    18% MODULARES  10.0  100.00        9.8
# 1245972              NSG   9.0   96.87        9.8
# 1245973           11% PI  10.0   76.41        9.8
# 1245974     15% QUIEBRES  10.0    1.24        9.8
# 1245975  20% STOCK BINEO   9.0   51.86        9.8
#
#                                         local      mercado.1  month  year  \
# 1245971  0992  SBA LONCOCHE                    869  RM - XIV      5  2022
# ...

# %%
#df_segmento_lider = data.groupby(['year', 'month', 'quarter']).mean()['disponota']
#df_segmento_lider.head()
#df_lider = data[data['formato'] == 819' LIDER']
#df_express = data[data['formato'] == 2022]
#df_sba = data[data['formato'] == 2022]

# %%
#Disponota a total general 
df_segmento = data.groupby(['formato', 'year', 'quarter']).mean()['disponota']
df_segmento
# Out:
# formato           year  quarter
# 200  EXPRESS 400  2021  2          8.174443
#                         3          8.137872
#                         4          7.770655
#                   2022  1          7.662533
#                         2          7.860253
# 815  BOD ACUENTA  2021  2          6.126400
#                         3          6.895079
#                         4          7.097536
#                   2022  1          7.379865
#                         2          7.475791
# 819  LIDER        2021  2          6.685036
#                         3          7.692704
#                         4          7.307230
#                   2022  1          7.198106
#                         2          7.675223
# 826  EXPRESS      2021  2          7.429240
#                         3          7.599427
#                         4          7.305619
#                   2022  1          7.524056
#                         2          7.965102
# 890  MAYORISTA    2021  2          5.805677
# ...

# %%
#GRAFICO DE LA DISPONOTA TOTAL 
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(14, 8))

#FILTROS DE DATA
df_lider = data[data['cod_formato'].isin(['819'])]
df_express = data[data['cod_formato'].isin(['826'])]
df_express_400 = data[data['cod_formato'].isin(['200'])]
df_sba = data[data['cod_formato'].isin(['815'])]

#group BY
df_segmento1 = df_lider.groupby(['year', 'quarter']).mean()['disponota']
df_segmento2 = df_express.groupby(['year', 'quarter']).mean()['disponota']
df_segmento3 = df_express_400.groupby(['year', 'quarter']).mean()['disponota']
df_segmento4 = df_sba.groupby(['year', 'quarter']).mean()['disponota']


df_segmento1.plot(ax=ax1, kind='bar', color='b', ylabel='Disponota', xlabel='month/quarter', title='Media Disponota Lider')
df_segmento2.plot(ax=ax2, kind='bar', color='g', ylabel='Disponota', xlabel='month/quarter' , title='Media Disponota Express')
df_segmento3.plot(ax=ax3, kind='bar', color='g', ylabel='Disponota', xlabel='month/quarter' , title='Media Disponota Express 400')
df_segmento4.plot(ax=ax4, kind='bar', color='r', ylabel='Disponota', xlabel='month/quarter' , title='Media Disponota SBA')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.9)

plt.show()
# Out:
# /Users/aromerq/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
#analizo indicadores formato lider
df_lider.head()
# Out:
#          fecha  cod_formato     formato               mercado  store_nbr  \
# 3   2021-05-01          819  819  LIDER  848  Mercado Lider 4        671
# 13  2021-05-01          819  819  LIDER  863  Mercado Lider 9         75
# 16  2021-05-01          819  819  LIDER  848  Mercado Lider 4        671
# 17  2021-05-01          819  819  LIDER  848  Mercado Lider 4        671
# 21  2021-05-01          819  819  LIDER  863  Mercado Lider 9         75
#
#               indicador  nota    kpi  disponota  \
# 3   10% INCONSISTENCIAS  10.0   2.67       7.34
# 13    8% ADHERENCIA CAT   1.0  22.09       5.40
# 16    8% ADHERENCIA CAT   9.0  88.15       7.34
# 17        18% MODULARES   8.0  96.08       7.34
# 21        18% MODULARES   4.0  78.50       5.40
#
#                                    local             mercado.1  month  year  \
# 3   0671  HI QUILICURA (LO MARCOLETA)     848  Mercado Lider 4      5  2021
# 13  0075  HI MAIPU                        863  Mercado Lider 9      5  2021
# ...

# %%
#La media de la Disponota del formato lider es: 7.3  
#df_lider.describe()
#df_express.describe()
#df_express_400.describe()
df_sba.describe()
# Out:
#        cod_formato      store_nbr           nota           kpi      disponota  \
# count     398993.0  398993.000000  398993.000000  3.989930e+05  398993.000000
# mean         815.0     543.402741       6.865584  5.782762e+02       7.008847
# std            0.0     211.891343       2.846993  6.672209e+04       1.252463
# min          815.0       7.000000       1.000000  0.000000e+00       0.180000
# 25%          815.0     505.000000       4.000000  5.050000e+00       6.270000
# 50%          815.0     559.000000       7.000000  3.851000e+01       7.170000
# 75%          815.0     594.000000      10.000000  8.970000e+01       7.880000
# max          815.0     996.000000      10.000000  1.096830e+07      10.000000
#
#                month           year        quarter
# count  398993.000000  398993.000000  398993.000000
# mean        6.474485    2021.354663       2.493472
# std         3.437581       0.478412       1.112469
# min         1.000000    2021.000000       1.000000
# ...

# %%
#La media de la Disponota del formato lider es: 7.3  
df_lider.groupby(['mercado']).mean()['disponota']
df_express.groupby(['mercado']).mean()['disponota'] 
df_express_400.groupby(['mercado']).mean()['disponota']
df_sba.groupby(['mercado']).mean()['disponota']
# Out:
# mercado
# 810  RM - V Interior     6.554596
# 812  RM - IX Sur         7.364109
# 813  VIII - IX Norte     7.454564
# 814  RM - VI             6.555786
# 816  RM - X              7.323830
# 867  Centro Sur          6.766196
# 868  VIII Costa          6.853406
# 869  RM - XIV            7.131207
# 870  Norte - V Costa     7.281703
# 872  RM - Talca          6.854723
# 873  RM - Norte Chico    6.921895
# Name: disponota, dtype: float64

# %%
#APERTURA DEL NSG
df_lider_nsg = df_lider[df_lider['indicador'].isin(['NSG'])]
df_express_nsg = df_express[df_express['indicador'].isin(['NSG'])]
df_express_400_nsg = df_express_400[df_express_400['indicador'].isin(['NSG'])]
df_sba_nsg = df_sba[df_sba['indicador'].isin(['NSG'])]

# %%
#LA MEDIA DEL NSG en LIDER ES 6.8
#LA MEDIA DEL NSG en EXPRESS ES 7.3
#LA MEDIA DEL NSG en EXPRESS 400 ES 8.3
#LA MEDIA DEL NSG en SBA ES 6.0

#df_lider_nsg.describe()
#df_express_nsg.describe()  
#df_express_400_nsg.describe() 
#df_sba_nsg.describe()

# %%
df_lider_nsg.groupby(['indicador', 'mercado']).mean()['nota']
df_express_nsg.groupby(['indicador', 'mercado']).mean()['nota']
df_express_400_nsg.groupby(['indicador', 'mercado']).mean()['nota']
df_sba_nsg.groupby(['indicador', 'mercado']).mean()['nota']
# Out:
# indicador  mercado
# NSG        810  RM - V Interior     5.679919
#            812  RM - IX Sur         6.139754
#            813  VIII - IX Norte     6.893197
#            814  RM - VI             5.909253
#            816  RM - X              6.535633
#            867  Centro Sur          5.799306
#            868  VIII Costa          5.484894
#            869  RM - XIV            5.704926
#            870  Norte - V Costa     6.468041
#            872  RM - Talca          6.337320
#            873  RM - Norte Chico    5.863302
# Name: nota, dtype: float64

# %%
#GRAFICO DEL NSG POR FORMATO
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(14, 8))

#FILTROS DE DATA
df_lider_nsg       = df_lider[df_lider['indicador'].isin(['NSG'])]
df_express_nsg     = df_express[df_express['indicador'].isin(['NSG'])]
df_express_400_nsg = df_express_400[df_express_400['indicador'].isin(['NSG'])]
df_sba_nsg         = df_sba[df_sba['indicador'].isin(['NSG'])]

#group BY
df_segmento1 = df_lider_nsg.groupby(['year', 'quarter']).mean()['nota']
df_segmento2 = df_express_nsg.groupby(['year', 'quarter']).mean()['nota']
df_segmento3 = df_express_400_nsg.groupby(['year', 'quarter']).mean()['nota']
df_segmento4 = df_sba_nsg.groupby(['year', 'quarter']).mean()['nota']


df_segmento1.plot(ax=ax1, kind='bar', color='b', ylabel='nota', xlabel='month/quarter', title='Media nsg Lider')
df_segmento2.plot(ax=ax2, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Media nsg Express')
df_segmento3.plot(ax=ax3, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Media nsg Express 400')
df_segmento4.plot(ax=ax4, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='Media nsg SBA')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.9)

plt.show()
# Out:
# /Users/aromerq/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
#gráfica por KPI Disponota 
df_lider.head()
# Out:
#          fecha  cod_formato     formato               mercado  store_nbr  \
# 3   2021-05-01          819  819  LIDER  848  Mercado Lider 4        671
# 13  2021-05-01          819  819  LIDER  863  Mercado Lider 9         75
# 16  2021-05-01          819  819  LIDER  848  Mercado Lider 4        671
# 17  2021-05-01          819  819  LIDER  848  Mercado Lider 4        671
# 21  2021-05-01          819  819  LIDER  863  Mercado Lider 9         75
#
#               indicador  nota    kpi  disponota  \
# 3   10% INCONSISTENCIAS  10.0   2.67       7.34
# 13    8% ADHERENCIA CAT   1.0  22.09       5.40
# 16    8% ADHERENCIA CAT   9.0  88.15       7.34
# 17        18% MODULARES   8.0  96.08       7.34
# 21        18% MODULARES   4.0  78.50       5.40
#
#                                    local             mercado.1  month  year  \
# 3   0671  HI QUILICURA (LO MARCOLETA)     848  Mercado Lider 4      5  2021
# 13  0075  HI MAIPU                        863  Mercado Lider 9      5  2021
# ...

# %%
#APERTURA DISPONOTA POR KPI - HIPER 
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4,2, figsize=(20, 12))

#FILTROS DE DATA
df_lider_inc       = df_lider[df_lider['indicador'].isin(['10% INCONSISTENCIAS'])]
df_lider_pi       = df_lider[df_lider['indicador'].isin(['11% PI'])]
df_lider_llena       = df_lider[df_lider['indicador'].isin(['12% LLENAR GONDOLAS'])]
df_lider_quiebre       = df_lider[df_lider['indicador'].isin(['15% QUIEBRES'])]
df_lider_modu       = df_lider[df_lider['indicador'].isin(['18% MODULARES'])]
df_lider_bineo       = df_lider[df_lider['indicador'].isin(['20% STOCK BINEO'])]
df_lider_expi       = df_lider[df_lider['indicador'].isin(['6% EXACTITUD PI'])]
df_lider_adhe       = df_lider[df_lider['indicador'].isin(['8% ADHERENCIA CAT'])]


#df_express_nsg     = df_express[df_express['indicador'].isin(['NSG'])]
#df_express_400_nsg = df_express_400[df_express_400['indicador'].isin(['NSG'])]
#df_sba_nsg         = df_sba[df_sba['indicador'].isin(['NSG'])]

#group BY
df_segmento1 = df_lider_inc.groupby(['year', 'quarter']).mean()['nota']
df_segmento2 = df_lider_pi.groupby(['year', 'quarter']).mean()['nota']
df_segmento3 = df_lider_llena.groupby(['year', 'quarter']).mean()['nota']
df_segmento4 = df_lider_quiebre.groupby(['year', 'quarter']).mean()['nota']
df_segmento5 = df_lider_modu.groupby(['year', 'quarter']).mean()['nota']
df_segmento6 = df_lider_bineo.groupby(['year', 'quarter']).mean()['nota']
df_segmento7 = df_lider_expi.groupby(['year', 'quarter']).mean()['nota']
df_segmento8 = df_lider_adhe.groupby(['year', 'quarter']).mean()['nota']
#df_segmento2 = df_express_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento3 = df_express_400_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento4 = df_sba_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']


df_segmento1.plot(ax=ax1, kind='bar', color='b', ylabel='nota', xlabel='month/quarter', title='Inconsistencias')
df_segmento2.plot(ax=ax2, kind='bar', color='b', ylabel='nota', xlabel='month/quarter' , title='PI')
df_segmento3.plot(ax=ax3, kind='bar', color='b', ylabel='nota', xlabel='month/quarter' , title='Llenar góndolas')
df_segmento4.plot(ax=ax4, kind='bar', color='b', ylabel='nota', xlabel='month/quarter' , title='Quiebres')
df_segmento5.plot(ax=ax5, kind='bar', color='b', ylabel='nota', xlabel='month/quarter' , title='Modulares')
df_segmento6.plot(ax=ax6, kind='bar', color='b', ylabel='nota', xlabel='month/quarter' , title='Stock Bineo')
df_segmento7.plot(ax=ax7, kind='bar', color='b', ylabel='nota', xlabel='month/quarter' , title='Exactitud PI')
df_segmento8.plot(ax=ax8, kind='bar', color='b', ylabel='nota', xlabel='month/quarter' , title='Adherencia')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=1.5)

plt.show()
# Out:
# /Users/aromerq/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %%
df_lider.groupby(['indicador', 'year', 'quarter']).mean()['nota']
# Out:
# indicador            year  quarter
# 10% INCONSISTENCIAS  2021  2          8.466481
#                            3          9.457850
#                            4          9.192609
#                      2022  1          8.540815
#                            2          9.377296
# 11% PI               2021  2          3.145902
#                            3          4.259783
#                            4          4.026442
#                      2022  1          4.050726
#                            2          4.125275
# 12% LLENAR GONDOLAS  2021  2          6.321111
#                            3          7.555072
#                            4          7.853375
#                      2022  1          7.686661
#                            2          7.768577
# 15% QUIEBRES         2021  2          7.509815
#                            3          8.331884
#                            4          8.349216
#                      2022  1          6.088644
# ...

# %%
#APERTURA DISPONOTA POR KPI - EXPRESS
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4,2, figsize=(20, 12))


#FILTROS DE DATA
df_express_inc       = df_express[df_express['indicador'].isin(['10% INCONSISTENCIAS'])]
df_express_pi       = df_express[df_express['indicador'].isin(['11% PI'])]
df_express_llena       = df_express[df_express['indicador'].isin(['12% LLENAR GONDOLAS'])]
df_express_quiebre       = df_express[df_express['indicador'].isin(['15% QUIEBRES'])]
df_express_modu       = df_express[df_express['indicador'].isin(['18% MODULARES'])]
df_express_bineo       = df_express[df_express['indicador'].isin(['20% STOCK BINEO'])]
df_express_expi       = df_express[df_express['indicador'].isin(['6% EXACTITUD PI'])]
df_express_adhe       = df_express[df_express['indicador'].isin(['8% ADHERENCIA CAT'])]


#df_express_nsg     = df_express[df_express['indicador'].isin(['NSG'])]
#df_express_400_nsg = df_express_400[df_express_400['indicador'].isin(['NSG'])]
#df_sba_nsg         = df_sba[df_sba['indicador'].isin(['NSG'])]

#group BY
df_segmento1 = df_express_inc.groupby(['year', 'quarter']).mean()['nota']
df_segmento2 = df_express_pi.groupby(['year', 'quarter']).mean()['nota']
df_segmento3 = df_express_llena.groupby(['year', 'quarter']).mean()['nota']
df_segmento4 = df_express_quiebre.groupby(['year', 'quarter']).mean()['nota']
df_segmento5 = df_express_modu.groupby(['year', 'quarter']).mean()['nota']
df_segmento6 = df_express_bineo.groupby(['year', 'quarter']).mean()['nota']
df_segmento7 = df_express_expi.groupby(['year', 'quarter']).mean()['nota']
df_segmento8 = df_express_adhe.groupby(['year', 'quarter']).mean()['nota']
#df_segmento2 = df_express_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento3 = df_express_400_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento4 = df_sba_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']


df_segmento1.plot(ax=ax1, kind='bar', color='g', ylabel='nota', xlabel='month/quarter', title='Inconsistencias')
df_segmento2.plot(ax=ax2, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='PI')
df_segmento3.plot(ax=ax3, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Llenar góndolas')
df_segmento4.plot(ax=ax4, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Quiebres')
df_segmento5.plot(ax=ax5, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Modulares')
df_segmento6.plot(ax=ax6, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Stock Bineo')
df_segmento7.plot(ax=ax7, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Exactitud PI')
df_segmento8.plot(ax=ax8, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Adherencia')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=1.5)

plt.show()

# %%
#APERTURA DISPONOTA POR KPI - EXPRESS 400
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4,2, figsize=(20, 12))


#FILTROS DE DATA
df_express_400_inc       = df_express_400[df_express_400['indicador'].isin(['10% INCONSISTENCIAS'])]
df_express_400_pi       = df_express_400[df_express_400['indicador'].isin(['11% PI'])]
df_express_400_llena       = df_express_400[df_express_400['indicador'].isin(['12% LLENAR GONDOLAS'])]
df_express_400_quiebre       = df_express_400[df_express_400['indicador'].isin(['15% QUIEBRES'])]
df_express_400_modu       = df_express_400[df_express_400['indicador'].isin(['18% MODULARES'])]
df_express_400_bineo       = df_express_400[df_express_400['indicador'].isin(['20% STOCK BINEO'])]
df_express_400_expi       = df_express_400[df_express_400['indicador'].isin(['6% EXACTITUD PI'])]
df_express_400_adhe       = df_express_400[df_express_400['indicador'].isin(['8% ADHERENCIA CAT'])]


#df_express_nsg     = df_express[df_express['indicador'].isin(['NSG'])]
#df_express_400_nsg = df_express_400[df_express_400['indicador'].isin(['NSG'])]
#df_sba_nsg         = df_sba[df_sba['indicador'].isin(['NSG'])]

#group BY
df_segmento1 = df_express_400_inc.groupby(['year', 'quarter']).mean()['nota']
df_segmento2 = df_express_400_pi.groupby(['year', 'quarter']).mean()['nota']
df_segmento3 = df_express_400_llena.groupby(['year', 'quarter']).mean()['nota']
df_segmento4 = df_express_400_quiebre.groupby(['year', 'quarter']).mean()['nota']
df_segmento5 = df_express_400_modu.groupby(['year', 'quarter']).mean()['nota']
df_segmento6 = df_express_400_bineo.groupby(['year', 'quarter']).mean()['nota']
df_segmento7 = df_express_400_expi.groupby(['year', 'quarter']).mean()['nota']
df_segmento8 = df_express_400_adhe.groupby(['year', 'quarter']).mean()['nota']
#df_segmento2 = df_express_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento3 = df_express_400_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento4 = df_sba_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']


df_segmento1.plot(ax=ax1, kind='bar', color='g', ylabel='nota', xlabel='month/quarter', title='Inconsistencias')
df_segmento2.plot(ax=ax2, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='PI')
df_segmento3.plot(ax=ax3, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Llenar góndolas')
df_segmento4.plot(ax=ax4, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Quiebres')
df_segmento5.plot(ax=ax5, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Modulares')
df_segmento6.plot(ax=ax6, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Stock Bineo')
df_segmento7.plot(ax=ax7, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Exactitud PI')
df_segmento8.plot(ax=ax8, kind='bar', color='g', ylabel='nota', xlabel='month/quarter' , title='Adherencia')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=1.5)

plt.show()

# %%
#APERTURA DISPONOTA POR KPI - SBA
import matplotlib.pyplot as plt
import numpy as np

fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8)) = plt.subplots(4,2, figsize=(20, 12))


#FILTROS DE DATA
df_sba_inc       = df_sba[df_sba['indicador'].isin(['10% INCONSISTENCIAS'])]
df_sba_pi       = df_sba[df_sba['indicador'].isin(['11% PI'])]
df_sba_llena       = df_sba[df_sba['indicador'].isin(['12% LLENAR GONDOLAS'])]
df_sba_quiebre       = df_sba[df_sba['indicador'].isin(['15% QUIEBRES'])]
df_sba_modu       = df_sba[df_sba['indicador'].isin(['18% MODULARES'])]
df_sba_bineo       = df_sba[df_sba['indicador'].isin(['20% STOCK BINEO'])]
df_sba_expi       = df_sba[df_sba['indicador'].isin(['6% EXACTITUD PI'])]
df_sba_adhe       = df_sba[df_sba['indicador'].isin(['8% ADHERENCIA CAT'])]


#df_express_nsg     = df_express[df_express['indicador'].isin(['NSG'])]
#df_express_400_nsg = df_express_400[df_express_400['indicador'].isin(['NSG'])]
#df_sba_nsg         = df_sba[df_sba['indicador'].isin(['NSG'])]

#group BY
df_segmento1 = df_sba_inc.groupby(['year', 'quarter']).mean()['nota']
df_segmento2 = df_sba_pi.groupby(['year', 'quarter']).mean()['nota']
df_segmento3 = df_sba_llena.groupby(['year', 'quarter']).mean()['nota']
df_segmento4 = df_sba_quiebre.groupby(['year', 'quarter']).mean()['nota']
df_segmento5 = df_sba_modu.groupby(['year', 'quarter']).mean()['nota']
df_segmento6 = df_sba_bineo.groupby(['year', 'quarter']).mean()['nota']
df_segmento7 = df_sba_expi.groupby(['year', 'quarter']).mean()['nota']
df_segmento8 = df_sba_adhe.groupby(['year', 'quarter']).mean()['nota']
#df_segmento2 = df_express_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento3 = df_express_400_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
#df_segmento4 = df_sba_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']


df_segmento1.plot(ax=ax1, kind='bar', color='r', ylabel='nota', xlabel='month/quarter', title='Inconsistencias')
df_segmento2.plot(ax=ax2, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='PI')
df_segmento3.plot(ax=ax3, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='Llenar góndolas')
df_segmento4.plot(ax=ax4, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='Quiebres')
df_segmento5.plot(ax=ax5, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='Modulares')
df_segmento6.plot(ax=ax6, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='Stock Bineo')
df_segmento7.plot(ax=ax7, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='Exactitud PI')
df_segmento8.plot(ax=ax8, kind='bar', color='r', ylabel='nota', xlabel='month/quarter' , title='Adherencia')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=1.5)

plt.show()

# %%
#relación DIsponota / NSG
#df_lider.head()

#import matplotlib.pyplot as plt
#import numpy as np

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(14, 8))

#FILTROS DE DATA
df_lider_nsg       = df_lider[df_lider['indicador'].isin(['NSG'])]
df_express_nsg     = df_express[df_express['indicador'].isin(['NSG'])]
df_express_400_nsg = df_express_400[df_express_400['indicador'].isin(['NSG'])]
df_sba_nsg         = df_sba[df_sba['indicador'].isin(['NSG'])]

#group BY
df_segmento1 = df_lider_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
df_segmento2 = df_express_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
df_segmento3 = df_express_400_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']
df_segmento4 = df_sba_nsg.groupby(['indicador', 'year', 'quarter']).mean()['nota']


df_segmento1.plot(ax=ax1, kind='line', color='b', ylabel='nota', xlabel='month/quarter', title='Media nsg Lider')
df_segmento2.plot(ax=ax2, kind='line', color='g', ylabel='nota', xlabel='month/quarter' , title='Media nsg Express')
df_segmento3.plot(ax=ax3, kind='line', color='g', ylabel='nota', xlabel='month/quarter' , title='Media nsg Express 400')
df_segmento4.plot(ax=ax4, kind='line', color='r', ylabel='nota', xlabel='month/quarter' , title='Media nsg SBA')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.9)

plt.show()
# Out:
# /Users/aromerq/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# /Users/aromerq/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# /Users/aromerq/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():
# ...

# %%
nsg_dispo = df_lider_nsg.groupby(['fecha']).mean()[['nota', 'disponota']]

# %%
nsg_dispo

# %%
import matplotlib.pyplot as plt

f2022 = df_lider_nsg[df_lider_nsg['year'].isin(['2022'])]
f2021 = df_lider_nsg[df_lider_nsg['year'].isin(['2021'])]

nsg_dispo = f2022.groupby(['fecha']).mean()[['nota', 'disponota']]

fig, ax = plt.subplots(figsize=(24, 12))
ax.plot(nsg_dispo.index, nsg_dispo["nota"])
ax.plot(nsg_dispo.index, nsg_dispo["disponota"])
ax.set_xlabel("time")
ax.set_ylabel("nota")
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.9)
plt.xticks(rotation=90)
plt.show()
